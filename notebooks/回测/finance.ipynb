# %%
from hikyuu.interactive import *
sm.get_history_finance_all_fields()
# Out:
# [(0, '基本每股收益'),
#  (1, '扣除非经常性损益每股收益'),
#  (2, '每股未分配利润'),
#  (3, '每股净资产'),
#  (4, '每股资本公积金'),
#  (5, '净资产收益率'),
#  (6, '每股经营现金流量'),
#  (7, '资产负债表_货币资金'),
#  (8, '资产负债表_交易性金融资产'),
#  (9, '资产负债表_应收票据'),
#  (10, '资产负债表_应收账款'),
#  (11, '资产负债表_预付款项'),
#  (12, '资产负债表_其他应收款'),
#  (13, '资产负债表_应收关联公司款'),
#  (14, '资产负债表_应收利息'),
#  (15, '资产负债表_应收股利'),
#  (16, '资产负债表_存货'),
#  (17, '资产负债表_消耗性生物资产'),
#  (18, '资产负债表_一年内到期的非流动资产'),
#  (19, '资产负债表_其他流动资产'),
#  (20, '资产负债表_流动资产合计'),
#  (21, '资产负债表_可供出售金融资产'),
#  (22, '资产负债表_持有至到期投资'),
#  (23, '资产负债表_长期应收款'),
#  (24, '资产负债表_长期股权投资'),
#  (25, '资产负债表_投资性房地产'),
#  (26, '资产负债表_固定资产'),
#  (27, '资产负债表_在建工程'),
#  (28, '资产负债表_工程物资'),
#  (29, '资产负债表_固定资产清理'),
#  (30, '资产负债表_生产性生物资产'),
#  (31, '资产负债表_油气资产'),
#  (32, '资产负债表_无形资产'),
#  (33, '资产负债表_开发支出'),
#  (34, '资产负债表_商誉'),
#  (35, '资产负债表_长期待摊费用'),
#  (36, '资产负债表_递延所得税资产'),
#  (37, '资产负债表_其他非流动资产'),
#  (38, '资产负债表_非流动资产合计'),
#  (39, '资产负债表_资产总计'),
#  (40, '资产负债表_短期借款'),
#  (41, '资产负债表_交易性金融负债'),
# ...

# %%
stok = FINANCE(16)

k = get_kdata("sh688521", Query(-500, ktype = 'QUARTER') )


stok(k).plot()

# %%
help(get_kdata)
# Out:
# Help on built-in function get_kdata in module hikyuu.cpp.core313:
#
# get_kdata(...) method of pybind11_builtins.pybind11_detail_function_record_v1_msvc_md_mscver19 instance
#     get_kdata(*args, **kwargs)
#     Overloaded function.
#
#     1. get_kdata(arg0: str, arg1: hikyuu.cpp.core313.Query) -> hikyuu.cpp.core313.KData
#
#     2. get_kdata(market_code: str, start: typing.SupportsInt = 0, end: typing.SupportsInt = 9223372036854775807, ktype: str = 'DAY', recover_type: hikyuu.cpp.core313.Query.RecoverType = <RecoverType.NO_RECOVER: 0>) -> hikyuu.cpp.core313.KData
#
#     根据证券代码及起止位置获取 [start, end) 范围的 K 线数据
#
#         :param str market_code: 证券代码，如: 'sh000001'
#         :param int start: 起始索引
#         :param int end: 结束索引
#         :param Query.KType ktype: K 线类型, 'DAY'|'WEEK'|'MONTH'|'QUARTER'|'HALFYEAR'|'YEAR'|'MIN'|'MIN5'|'MIN15'|'MIN30'|'MIN60'
#         :param Query.RecoverType recover_type: 复权类型
#
# ...

# %%
help(stok)
# Out:
# Help on Indicator in module hikyuu.cpp.core313 object:
#
# class Indicator(pybind11_builtins.pybind11_object)
#  |  技术指标
#  |
#  |  Method resolution order:
#  |      Indicator
#  |      pybind11_builtins.pybind11_object
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __add__(...)
#  |      __add__(*args, **kwargs)
#  |      Overloaded function.
#  |
#  |      1. __add__(self: hikyuu.cpp.core313.Indicator, arg0: hikyuu.cpp.core313.Indicator) -> hikyuu.cpp.core313.Indicator
#  |
#  |      2. __add__(self: hikyuu.cpp.core313.Indicator, arg0: typing.SupportsFloat) -> hikyuu.cpp.core313.Indicator
#  |
#  |  __and__(...)
#  |      __and__(*args, **kwargs)
#  |      Overloaded function.
#  |
#  |      1. __and__(self: hikyuu.cpp.core313.Indicator, arg0: hikyuu.cpp.core313.Indicator) -> hikyuu.cpp.core313.Indicator
#  |
#  |      2. __and__(self: hikyuu.cpp.core313.Indicator, arg0: typing.SupportsFloat) -> hikyuu.cpp.core313.Indicator
#  |
#  |  __call__(...)
# ...

# %%
stok(k).to_df()
# Out:
#      datetime       value0
# 0  2020-09-30   80796240.0
# 1  2020-12-31   81863248.0
# 2  2021-03-31   83471064.0
# 3  2021-06-30   87756392.0
# 4  2021-09-30  107406520.0
# 5  2021-12-31  121983280.0
# 6  2022-03-31  133430256.0
# 7  2022-06-30  156708944.0
# 8  2022-09-30  138663616.0
# 9  2022-12-31  312962592.0
# 10 2023-03-31  422532512.0
# 11 2023-06-30  498022912.0
# 12 2023-09-30  515182816.0
# 13 2023-12-31  361148864.0
# 14 2024-03-31  278622688.0
# 15 2024-06-30  302950592.0
# 16 2024-09-30  305207872.0
# 17 2024-12-31  367264192.0
# 18 2025-03-31  367264192.0
# 19 2025-06-30  420432864.0
# 20 2025-09-30  445583264.0
# 21 2025-12-31  499580512.0
# 22 2026-03-31  497982720.0
# 23 2026-06-30  497982720.0
# 2026-04-26 00:00:00.008 [HKU-I] - start reload ... (StockManager.cpp:434)
# 2026-04-26 00:00:00.023 [HKU-I] - 加载市场信息…… (StockManager.cpp:795)
# 2026-04-26 00:00:00.026 [HKU-I] - 加载证券类型信息…… (StockManager.cpp:812)
# ...
