# %%
import financedatabase as fd

# Initialize the Equities database
equities = fd.Equities()

# Obtain all data available excluding international exchanges
all_equities = equities.select(exclude_exchanges=False)

# %%
all_equities[~all_equities['isin'].isnull()]
# Out:
#                                        name  \
# symbol
# 000002.SZ             China Vanke Co., Ltd.
# 000005.SZ     Shenzhen Fountain Corporation
# 000006.SZ  Shenzhen Zhenye (Group) Co.,Ltd.
# 000007.SZ     Shenzhen Quanxinhao Co., Ltd.
# 000009.SZ       China Baoan Group Co., Ltd.
# ...                                     ...
# ZYNE          Zynerba Pharmaceuticals, Inc.
# ZYR1.F                  Cornish Metals Inc.
# ZYW.F        China Properties Group Limited
# ZZ-B.ST                   Zinzino AB (publ)
# ZZD1.F             BC Craft Supply Co. Ltd.
#
#                                                      summary currency  \
# symbol
# 000002.SZ  China Vanke Co., Ltd., together with its subsi...      CNY
# 000005.SZ  Shenzhen Fountain Corporation engages in real ...      CNY
# 000006.SZ  Shenzhen Zhenye (Group) Co.,Ltd. engages in th...      CNY
# 000007.SZ  Shenzhen Quanxinhao Co., Ltd. owns and operate...      CNY
# 000009.SZ  China Baoan Group Co., Ltd., an investment hol...      CNY
# ...                                                      ...      ...
# ZYNE       Zynerba Pharmaceuticals, Inc. operates as a cl...      USD
# ZYR1.F     Cornish Metals Inc. engages in the acquisition...      EUR
# ZYW.F      China Properties Group Limited, an investment ...      EUR
# ZZ-B.ST    Zinzino AB (publ), a direct sales company, eng...      SEK
# ZZD1.F     BC Craft Supply Co. Ltd., together with its su...      EUR
#
#                            sector  \
# symbol
# 000002.SZ             Real Estate
# 000005.SZ             Real Estate
# 000006.SZ             Real Estate
# 000007.SZ  Consumer Discretionary
# 000009.SZ             Industrials
# ...                           ...
# ZYNE                  Health Care
# ZYR1.F                  Materials
# ZYW.F                 Real Estate
# ZZ-B.ST          Consumer Staples
# ZZD1.F                Health Care
#
#                                            industry_group  \
# symbol
# 000002.SZ                                     Real Estate
# 000005.SZ                                     Real Estate
# 000006.SZ                                     Real Estate
# 000007.SZ                               Consumer Services
# 000009.SZ                                   Capital Goods
# ...                                                   ...
# ZYNE       Pharmaceuticals, Biotechnology & Life Sciences
# ZYR1.F                                          Materials
# ZYW.F                                         Real Estate
# ZZ-B.ST                     Household & Personal Products
# ZZD1.F     Pharmaceuticals, Biotechnology & Life Sciences
#
#                                        industry exchange  \
# symbol
# 000002.SZ  Real Estate Management & Development      SHZ
# 000005.SZ  Real Estate Management & Development      SHZ
# 000006.SZ  Real Estate Management & Development      SHZ
# 000007.SZ         Hotels, Restaurants & Leisure      SHZ
# 000009.SZ              Industrial Conglomerates      SHZ
# ...                                         ...      ...
# ZYNE                            Pharmaceuticals      NGM
# ZYR1.F                          Metals & Mining      FRA
# ZYW.F      Real Estate Management & Development      FRA
# ZZ-B.ST                      Household Products      STO
# ZZD1.F                          Pharmaceuticals      FRA
#
#                              market        country state        city  zipcode  \
# symbol
# 000002.SZ   Shenzhen Stock Exchange          China   NaN    Shenzhen   518083
# 000005.SZ   Shenzhen Stock Exchange          China   NaN    Shenzhen   518001
# 000006.SZ   Shenzhen Stock Exchange          China   NaN    Shenzhen   518008
# 000007.SZ   Shenzhen Stock Exchange          China   NaN    Shenzhen   518031
# 000009.SZ   Shenzhen Stock Exchange          China   NaN    Shenzhen   518020
# ...                             ...            ...   ...         ...      ...
# ZYNE           Nordic Growth Market  United States    PA       Devon    19333
# ZYR1.F     Frankfurt Stock Exchange         Canada    BC   Vancouver  V6C 1H2
# ZYW.F      Frankfurt Stock Exchange      Hong Kong   NaN     Central      NaN
# ZZ-B.ST        NASDAQ OMX Stockholm         Sweden   NaN  Gothenburg   421 32
# ZZD1.F     Frankfurt Stock Exchange         Canada    BC   Vancouver  V6C 2V6
#
#                                 website market_cap          isin      cusip  \
# symbol
# 000002.SZ          http://www.vanke.com  Large Cap  CNE100001SR9        NaN
# 000005.SZ    http://www.fountain.com.cn  Small Cap  CNE0000001L7        NaN
# 000006.SZ         http://www.zhenye.com  Small Cap  CNE000000164        NaN
# 000007.SZ       http://www.sz000007.com  Micro Cap  CNE0000000P0        NaN
# 000009.SZ     http://www.chinabaoan.com    Mid Cap  CNE000000222        NaN
# ...                                 ...        ...           ...        ...
# ZYNE                 http://zynerba.com  Micro Cap  US98986X1090  98986X109
# ZYR1.F     http://www.cornishmetals.com  Micro Cap  CA21948L1040        NaN
# ZYW.F          http://www.cpg-group.com  Micro Cap  KYG2159A1058        NaN
# ZZ-B.ST          http://www.zinzino.com  Micro Cap  SE0002480442        NaN
# ZZD1.F          http://bccraftsupply.ca   Nano Cap  CA07335D2014        NaN
#
#                    figi composite_figi shareclass_figi
# symbol
# 000002.SZ           NaN            NaN             NaN
# 000005.SZ           NaN            NaN             NaN
# 000006.SZ           NaN            NaN             NaN
# 000007.SZ           NaN            NaN             NaN
# 000009.SZ           NaN            NaN             NaN
# ...                 ...            ...             ...
# ZYNE                NaN            NaN             NaN
# ZYR1.F     BBG000BZ7KR8   BBG000BZ7KF1    BBG001SBG3K6
# ZYW.F               NaN            NaN             NaN
# ZZ-B.ST             NaN            NaN             NaN
# ZZD1.F              NaN            NaN             NaN
#
# [39335 rows x 19 columns]

# %%
# all_equities = all_equities.drop(columns = 'summary')
all_equities.to_csv('stocks.csv')

# %%
all_equities
# Out:
#                                                name currency  \
# symbol
# 000002.SZ                     China Vanke Co., Ltd.      CNY
# 000004.SZ                                       two      CNY
# 000005.SZ             Shenzhen Fountain Corporation      CNY
# 000006.SZ          Shenzhen Zhenye (Group) Co.,Ltd.      CNY
# 000007.SZ             Shenzhen Quanxinhao Co., Ltd.      CNY
# ...                                             ...      ...
# ZZZOF                                           one      USD
# NaN        Nano Labs Ltd American Depositary Shares      USD
# NaN        Nano Labs Ltd American Depositary Shares      USD
# NaN        Nano Labs Ltd American Depositary Shares      USD
# NaN        Nano Labs Ltd American Depositary Shares      USD
#
#                            sector                            industry_group  \
# symbol
# 000002.SZ             Real Estate                               Real Estate
# 000004.SZ              Financials                    Diversified Financials
# 000005.SZ             Real Estate                               Real Estate
# 000006.SZ             Real Estate                               Real Estate
# 000007.SZ  Consumer Discretionary                         Consumer Services
# ...                           ...                                       ...
# ZZZOF                  Financials                    Diversified Financials
# NaN        Information Technology  Semiconductors & Semiconductor Equipment
# NaN        Information Technology  Semiconductors & Semiconductor Equipment
# NaN        Information Technology  Semiconductors & Semiconductor Equipment
# NaN        Information Technology  Semiconductors & Semiconductor Equipment
#
#                                            industry exchange  \
# symbol
# 000002.SZ      Real Estate Management & Development      SHZ
# 000004.SZ            Diversified Financial Services      SHZ
# 000005.SZ      Real Estate Management & Development      SHZ
# 000006.SZ      Real Estate Management & Development      SHZ
# 000007.SZ             Hotels, Restaurants & Leisure      SHZ
# ...                                             ...      ...
# ZZZOF                Diversified Financial Services      PNK
# NaN        Semiconductors & Semiconductor Equipment      NMS
# NaN        Semiconductors & Semiconductor Equipment      NMS
# NaN        Semiconductors & Semiconductor Equipment      NMS
# NaN        Semiconductors & Semiconductor Equipment      NMS
#
#                             market        country state           city  \
# symbol
# 000002.SZ  Shenzhen Stock Exchange          China   NaN       Shenzhen
# 000004.SZ  Shenzhen Stock Exchange  United States    CA  San Francisco
# 000005.SZ  Shenzhen Stock Exchange          China   NaN       Shenzhen
# 000006.SZ  Shenzhen Stock Exchange          China   NaN       Shenzhen
# 000007.SZ  Shenzhen Stock Exchange          China   NaN       Shenzhen
# ...                            ...            ...   ...            ...
# ZZZOF           OTC Bulletin Board  United States    CA  San Francisco
# NaN           NASDAQ Global Select          China   NaN            NaN
# NaN           NASDAQ Global Select          China   NaN            NaN
# NaN           NASDAQ Global Select          China   NaN            NaN
# NaN           NASDAQ Global Select          China   NaN            NaN
#
#           zipcode                     website market_cap          isin cusip  \
# symbol
# 000002.SZ  518083        http://www.vanke.com  Large Cap  CNE100001SR9   NaN
# 000004.SZ   94129      http://www.sz000004.cn  Micro Cap           NaN   NaN
# 000005.SZ  518001  http://www.fountain.com.cn  Small Cap  CNE0000001L7   NaN
# 000006.SZ  518008       http://www.zhenye.com  Small Cap  CNE000000164   NaN
# 000007.SZ  518031     http://www.sz000007.com  Micro Cap  CNE0000000P0   NaN
# ...           ...                         ...        ...           ...   ...
# ZZZOF       94129        http://www.a-star.co  Small Cap           NaN   NaN
# NaN           NaN                         NaN   Nano Cap           NaN   NaN
# NaN           NaN                         NaN   Nano Cap           NaN   NaN
# NaN           NaN                         NaN   Nano Cap           NaN   NaN
# NaN           NaN                         NaN   Nano Cap           NaN   NaN
#
#           figi composite_figi shareclass_figi
# symbol
# 000002.SZ  NaN            NaN             NaN
# 000004.SZ  NaN            NaN             NaN
# 000005.SZ  NaN            NaN             NaN
# 000006.SZ  NaN            NaN             NaN
# 000007.SZ  NaN            NaN             NaN
# ...        ...            ...             ...
# ZZZOF      NaN            NaN             NaN
# NaN        NaN            NaN             NaN
# NaN        NaN            NaN             NaN
# NaN        NaN            NaN             NaN
# NaN        NaN            NaN             NaN
#
# [158591 rows x 18 columns]

# %%
import requests
import pandas as pd
import json
import re
import os
from bs4 import BeautifulSoup
# from investin.Utils.config import data_dir
data_dir = 'investin/data'
save_path = data_dir + '/static/TradingView/isin.csv'
initiated = os.path.exists(save_path)

def fetch_global_prices():
    country = 'global'
    columns = '["name","description","logoid","type","close","currency","change","Value.Traded","market_cap_basic","fundamental_currency_code","sector","industry","market","is_primary","exchange","country"]'
    payload = '{"columns":'+ columns +',"filter":[{"left":"typespecs","operation":"has_none_of","right":["etn","etf"]}],"ignore_unknown_fields":false,"price_conversion":{"to_currency":"usd"},"range":[0,90000],"sort":{"sortBy":"market_cap_basic","sortOrder":"desc"},"markets":["america","argentina","australia","bahrain","belgium","brazil","canada","chile","china","colombia","cyprus","denmark","egypt","estonia","finland","france","germany","greece","hongkong","hungary","iceland","india","indonesia","israel","italy","japan","kenya","kuwait","latvia","lithuania","luxembourg","malaysia","mexico","morocco","netherlands","newzealand","nigeria","norway","pakistan","peru","philippines","poland","portugal","qatar","romania","russia","ksa","serbia","singapore","slovakia","rsa","korea","spain","srilanka","sweden","switzerland","taiwan","thailand","tunisia","turkey","uae","uk","venezuela","vietnam"]}'
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36'}

    url = 'https://scanner.tradingview.com/' + country + '/scan'
    r = requests.post(url, headers = headers, data = payload, timeout=10).text
    df_data = pd.DataFrame(json.loads(r)['data'])['d']
    df_data = pd.DataFrame(df_data.tolist(), index = df_data.index, columns = json.loads(columns))
    df_s    = pd.DataFrame(json.loads(r)['data'])['s']
    df_s    = pd.DataFrame(df_s.tolist(), index = df_s.index, columns = ['full_symbol'])
    df = pd.concat([df_s, df_data], axis=1)
    return df

def get_primay_symbol_list():
    df = fetch_global_prices()
    symbol_list = list(df[df['is_primary'] == True]['full_symbol'].str.replace(':','-'))
    return symbol_list

def get_isin(symbol_string):
    url = 'https://www.tradingview.com/symbols/{symbol_string}/?route_range=full'.format(symbol_string = symbol_string)
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36'}
    html = requests.get(url, headers = headers, timeout=10).text
    soup = BeautifulSoup(html, "html.parser")
    scripts = soup.find_all("script", type="application/prs.init-data+json")
    symbol_dict = list(json.loads(scripts[2].text).values())[0]['data']['symbol']
    df = pd.DataFrame(list(json.loads(scripts[2].text).values())[0]['data']['related_symbols']['stocks']['data'])
    df['primary_symbol'] = symbol_dict['pro_symbol']
    df['ticker_title'] = symbol_dict['ticker_title']
    return df

def update_result(df):
    df.to_csv(save_path, mode='a',index = False, header=not initiated, encoding = 'utf-8')

    
def get_fetched_list():
    fetched_list = list(pd.read_csv(save_path)['primary_symbol'].unique()) if initiated else []
    return fetched_list
        
    
# fetched_list = get_fetched_list()
# symbol_list = get_primay_symbol_list().difference(fetched_list)

# for symbol_string in symbol_list[:2]:
#     df = get_isin(symbol_string)
#     update_result(df)

# %%
symbol_string = 'LSE:SHEL'
url = 'https://www.tradingview.com/symbols/{symbol_string}/?route_range=full'.format(symbol_string = symbol_string)
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36'}
html = requests.get(url, headers = headers, timeout=10).text
soup = BeautifulSoup(html, "html.parser")
scripts = soup.find_all("script", type="application/prs.init-data+json")

# %%
list(json.loads(scripts[2].text).values())[0]['data']['symbol']
# Out:
# {'pro_symbol': 'LSE:SHEL',
#  'short_name': 'SHEL',
#  'exchange': 'LSE',
#  'type': 'stock',
#  'typespecs': ['common'],
#  'tv_symbol_page_url_force_exchange': ['/symbols/LSE-SHEL/', ''],
#  'ticker_title': 'SHELL PLC ORD EUR0.07',
#  'instrument_name': 'SHELL PLC ORD EUR0.07',
#  'medium_logo_urls': ['https://s3-symbol-logo.tradingview.com/shell.svg'],
#  'logo_id': 'shell',
#  'is_primary_listing': True,
#  'description': 'SHELL PLC ORD EUR0.07',
#  'is_derived_data': False,
#  'large_logo_urls': ['https://s3-symbol-logo.tradingview.com/shell--big.svg'],
#  'currency': 'GBX',
#  'country': 'gb',
#  'source_logo_url': 'https://s3-symbol-logo.tradingview.com/country/GB.svg',
#  'exchange_for_display': 'LSE',
#  'is_shariah_compliant': False}

# %%
symbol_string = 'LSE:SHEL'
df = get_isin(symbol_string)
df
# Out:
#             fullname short_name exchange_for_display  \
# 0           LSE:SHEL       SHEL                  LSE
# 1     EURONEXT:SHELL      SHELL             Euronext
# 2          NYSE:SHEL       SHEL                 NYSE
# 3          XETR:R6C0       R6C0                 XETR
# 4    TURQUOISE:SHELL      SHELL            Turquoise
# 5     TRADEGATE:R6C0       R6C0            TRADEGATE
# 6          BCBA:SHEL       SHEL                 BYMA
# 7          OTC:RYDAF      RYDAF                  OTC
# 8           FWB:R6C0       R6C0                  FWB
# 9        PSECZ:SHELL      SHELL                  PSE
# 10       GETTEX:R6C0       R6C0               GETTEX
# 11  TURQUOISE:SHELLA     SHELLA            Turquoise
# 12        BCBA:SHELD      SHELD                 BYMA
# 13          SWB:R6C0       R6C0                  SWB
# 14        BCBA:SHELB      SHELB                 BYMA
# 15        BMV:SHEL/N     SHEL/N                  BMV
# 16          MUN:R6C0       R6C0                  MUN
# 17           BX:R6C0       R6C0                   BX
# 18       BMV:SHEL1/N    SHEL1/N                  BMV
# 19          BER:R6C0       R6C0                  BER
# 20           FWB:L3H        L3H                  FWB
# 21     TRADEGATE:L3H        L3H            TRADEGATE
# 22          DUS:R6C0       R6C0                  DUS
# 23          HAM:R6C0       R6C0                  HAM
# 24          HAN:R6C0       R6C0                  HAN
# 25           DUS:L3H        L3H                  DUS
# 26           SWB:L3H        L3H                  SWB
# 27           BER:L3H        L3H                  BER
# 28        BCBA:SHELC      SHELC                 BYMA
# 29           MUN:L3H        L3H                  MUN
# 30        GETTEX:L3H        L3H               GETTEX
#
#                                       source_logo_url  \
# 0   https://s3-symbol-logo.tradingview.com/country...
# 1   https://s3-symbol-logo.tradingview.com/country...
# 2   https://s3-symbol-logo.tradingview.com/country...
# 3   https://s3-symbol-logo.tradingview.com/country...
# 4   https://s3-symbol-logo.tradingview.com/country...
# 5   https://s3-symbol-logo.tradingview.com/country...
# 6   https://s3-symbol-logo.tradingview.com/country...
# 7   https://s3-symbol-logo.tradingview.com/country...
# 8   https://s3-symbol-logo.tradingview.com/country...
# 9   https://s3-symbol-logo.tradingview.com/country...
# 10  https://s3-symbol-logo.tradingview.com/country...
# 11  https://s3-symbol-logo.tradingview.com/country...
# 12  https://s3-symbol-logo.tradingview.com/country...
# 13  https://s3-symbol-logo.tradingview.com/country...
# 14  https://s3-symbol-logo.tradingview.com/country...
# 15  https://s3-symbol-logo.tradingview.com/country...
# 16  https://s3-symbol-logo.tradingview.com/country...
# 17  https://s3-symbol-logo.tradingview.com/country...
# 18  https://s3-symbol-logo.tradingview.com/country...
# 19  https://s3-symbol-logo.tradingview.com/country...
# 20  https://s3-symbol-logo.tradingview.com/country...
# 21  https://s3-symbol-logo.tradingview.com/country...
# 22  https://s3-symbol-logo.tradingview.com/country...
# 23  https://s3-symbol-logo.tradingview.com/country...
# 24  https://s3-symbol-logo.tradingview.com/country...
# 25  https://s3-symbol-logo.tradingview.com/country...
# 26  https://s3-symbol-logo.tradingview.com/country...
# 27  https://s3-symbol-logo.tradingview.com/country...
# 28  https://s3-symbol-logo.tradingview.com/country...
# 29  https://s3-symbol-logo.tradingview.com/country...
# 30  https://s3-symbol-logo.tradingview.com/country...
#
#             tv_symbol_page_url currency_code          isin  \
# 0           /symbols/LSE-SHEL/           GBX  GB00BP6MXD84
# 1     /symbols/EURONEXT-SHELL/           EUR  GB00BP6MXD84
# 2          /symbols/NYSE-SHEL/           USD  US7802593050
# 3          /symbols/XETR-R6C0/           EUR  GB00BP6MXD84
# 4    /symbols/TURQUOISE-SHELL/           GBX  GB00BP6MXD84
# 5     /symbols/TRADEGATE-R6C0/           EUR  GB00BP6MXD84
# 6          /symbols/BCBA-SHEL/           ARS  ARDEUT112547
# 7          /symbols/OTC-RYDAF/           USD  GB00BP6MXD84
# 8           /symbols/FWB-R6C0/           EUR  GB00BP6MXD84
# 9        /symbols/PSECZ-SHELL/           CZK  GB00BP6MXD84
# 10       /symbols/GETTEX-R6C0/           EUR  GB00BP6MXD84
# 11  /symbols/TURQUOISE-SHELLA/           EUR  GB00BP6MXD84
# 12        /symbols/BCBA-SHELD/           USD  ARDEUT112547
# 13          /symbols/SWB-R6C0/           EUR  GB00BP6MXD84
# 14        /symbols/BCBA-SHELB/           ARS  ARDEUT112547
# 15        /symbols/BMV-SHEL/N/           MXN  GB00BP6MXD84
# 16          /symbols/MUN-R6C0/           EUR  GB00BP6MXD84
# 17           /symbols/BX-R6C0/           CHF  GB00BP6MXD84
# 18       /symbols/BMV-SHEL1/N/           MXN  US7802593050
# 19          /symbols/BER-R6C0/           EUR  GB00BP6MXD84
# 20           /symbols/FWB-L3H/           EUR  US7802593050
# 21     /symbols/TRADEGATE-L3H/           EUR  US7802593050
# 22          /symbols/DUS-R6C0/           EUR  GB00BP6MXD84
# 23          /symbols/HAM-R6C0/           EUR  GB00BP6MXD84
# 24          /symbols/HAN-R6C0/           EUR  GB00BP6MXD84
# 25           /symbols/DUS-L3H/           EUR  US7802593050
# 26           /symbols/SWB-L3H/           EUR  US7802593050
# 27           /symbols/BER-L3H/           EUR  US7802593050
# 28        /symbols/BCBA-SHELC/           USD  ARDEUT112547
# 29           /symbols/MUN-L3H/           EUR  US7802593050
# 30        /symbols/GETTEX-L3H/           EUR  US7802593050
#
#     is_primary_listing primary_symbol           ticker_title
# 0                 True       LSE:SHEL  SHELL PLC ORD EUR0.07
# 1                False       LSE:SHEL  SHELL PLC ORD EUR0.07
# 2                False       LSE:SHEL  SHELL PLC ORD EUR0.07
# 3                False       LSE:SHEL  SHELL PLC ORD EUR0.07
# 4                False       LSE:SHEL  SHELL PLC ORD EUR0.07
# 5                False       LSE:SHEL  SHELL PLC ORD EUR0.07
# 6                False       LSE:SHEL  SHELL PLC ORD EUR0.07
# 7                False       LSE:SHEL  SHELL PLC ORD EUR0.07
# 8                False       LSE:SHEL  SHELL PLC ORD EUR0.07
# 9                False       LSE:SHEL  SHELL PLC ORD EUR0.07
# 10               False       LSE:SHEL  SHELL PLC ORD EUR0.07
# 11               False       LSE:SHEL  SHELL PLC ORD EUR0.07
# 12               False       LSE:SHEL  SHELL PLC ORD EUR0.07
# 13               False       LSE:SHEL  SHELL PLC ORD EUR0.07
# 14               False       LSE:SHEL  SHELL PLC ORD EUR0.07
# 15               False       LSE:SHEL  SHELL PLC ORD EUR0.07
# 16               False       LSE:SHEL  SHELL PLC ORD EUR0.07
# 17               False       LSE:SHEL  SHELL PLC ORD EUR0.07
# 18               False       LSE:SHEL  SHELL PLC ORD EUR0.07
# 19               False       LSE:SHEL  SHELL PLC ORD EUR0.07
# 20               False       LSE:SHEL  SHELL PLC ORD EUR0.07
# 21               False       LSE:SHEL  SHELL PLC ORD EUR0.07
# 22               False       LSE:SHEL  SHELL PLC ORD EUR0.07
# 23               False       LSE:SHEL  SHELL PLC ORD EUR0.07
# 24               False       LSE:SHEL  SHELL PLC ORD EUR0.07
# 25               False       LSE:SHEL  SHELL PLC ORD EUR0.07
# 26               False       LSE:SHEL  SHELL PLC ORD EUR0.07
# 27               False       LSE:SHEL  SHELL PLC ORD EUR0.07
# 28               False       LSE:SHEL  SHELL PLC ORD EUR0.07
# 29               False       LSE:SHEL  SHELL PLC ORD EUR0.07
# 30               False       LSE:SHEL  SHELL PLC ORD EUR0.07
