# %%
import pandas as pd
import akshare as ak

# %%
df = ak.stock_board_concept_name_em()
# df.to_csv('概念列表.csv', index =  False)
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File ~\AppData\Local\miniconda3\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# ...

# %%
import requests

def get_concept_reasons(page):
    url = 'https://datacenter.eastmoney.com/securities/api/data/v1/get'
    payload = {
        'reportName':'RPT_F10_CORETHEME_BOARDTYPE',
        'columns':'SECUCODE,SECURITY_NAME_ABBR,BOARD_NAME,SELECTED_BOARD_REASON',
        'quoteColumns':'f3~05~NEW_BOARD_CODE~BOARD_YIELD',
        'filter':'(IS_PRECISE="1")',
        'pageNumber': page,
        'pageSize':'',
        'sortTypes':'1',
        'sortColumns':'BOARD_RANK',
        'source':'HSF10',
        'client':'PC',
        'v':'05379500850666044',
    }
    r = requests.get(url, params = payload)
    df = pd.DataFrame(r.json()['result']['data']).drop(columns=['BOARD_YIELD'])
    return df

total_df = pd.DataFrame()
for page in range(1,5):
    df = get_concept_reasons(page)
    total_df = pd.concat([total_df,df])
total_df.columns = ['证券代码','股票名称','概念名称','概念解析']

# %%
total_df.columns = ['证券代码','股票名称','概念名称','概念解析']
total_df['概念名称'] = total_df['概念名称'].str.replace('概念','')
total_df = total_df.drop_duplicates()

# %%
total_df
# Out:
#            证券代码  股票名称  概念名称                                               概念解析
# 0     A19082.SH  三元基因  基因测序  2020年12月24日回复称公司在高稳定性蛋白质药物水溶液、高效长效低毒干扰素、乙肝患者基因...
# 1     603360.SH  百傲化学   半导体  2024年2月1日发布公告,公司与苏州芯慧联半导体科技有限公司(简称“芯慧联”)拟签订《战略...
# 2     605580.SH  恒盛能源  绿色电力   2021年8月6日招股书显示子公司恒鑫电力是浙江省内首家以农林废弃物为燃料的生物质热电联产项目。
# 3     603235.SH  天新药业   维生素  2022年6月23日回复称公司主要从事单体维生素产品的研发、生产与销售,产品包括维生素 B6...
# 4     002676.SZ  顺威股份  新能源车  2022年8月24日回复称公司子公司广州顺威新能源汽车有限公司以汽车精密注塑、精密模具、汽车...
# ...         ...   ...   ...                                                ...
# 2132  300166.SZ  东方国信   物联网  2020年5月13日回复称公司将工业大数据分析与挖掘技术、工业BIM、人工智能(语音识别、图...
# 2133  600522.SH  中天科技   新材料  2020年10月23日回复称公司光掩膜高纯石英基板产品指标试用合格,正按项目计划开展产业化建...
# 2134  600522.SH  中天科技    创投                  2020年半年报显示公司有如东融创毅达创业投资基金(有限合伙) 。
# 2135  600522.SH  中天科技   新能源  2020年半年报显示公司自主开发建设运营的分布式光伏电站规模达344.6MWp,在“自发自用...
# 2136  600522.SH  中天科技    军工                       2019年9月12日回复称公司部分产品有为国防军工供货。
#
# ...

# %%
total_df.to_csv('concept_reasons.csv', index = False)
