# %%
from selenium import webdriver

options = webdriver.FirefoxOptions()
driver = webdriver.Firefox(options=options)
options.add_argument("--headless")
# chrome_options.headless = True # also works
driver = webdriver.Chrome(options=chrome_options)
driver.get('https://wenda.tdx.com.cn/site/wenda/stock_index.html?message=%E6%89%80%E5%B1%9E%E6%A6%82%E5%BF%B5%EF%BC%8C%E5%85%AC%E5%8F%B8%E5%9C%B0%E4%BD%8D%EF%BC%8C%E6%89%80%E5%B1%9E%E8%A1%8C%E4%B8%9A')    
driver.get_cookies()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/selenium/webdriver/common/selenium_manager.py:112, in SeleniumManager.run(args)
#     111 try:
# --> 112     completed_proc = subprocess.run(args, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
#     113     stdout = completed_proc.stdout.decode("utf-8").rstrip("\n")
#
# File /usr/lib/python3.10/subprocess.py:501, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     499     kwargs['stderr'] = PIPE
# --> 501 with Popen(*popenargs, **kwargs) as process:
#     502     try:
#
# File /usr/lib/python3.10/subprocess.py:969, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize)
#     966             self.stderr = io.TextIOWrapper(self.stderr,
#     967                     encoding=encoding, errors=errors)
# --> 969     self._execute_child(args, executable, preexec_fn, close_fds,
#     970                         pass_fds, cwd, env,
#     971                         startupinfo, creationflags, shell,
#     972                         p2cread, p2cwrite,
#     973                         c2pread, c2pwrite,
#     974                         errread, errwrite,
#     975                         restore_signals,
#     976                         gid, gids, uid, umask,
#     977                         start_new_session)
#     978 except:
#     979     # Cleanup if the child failed starting.
#
# File /usr/lib/python3.10/subprocess.py:1845, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#    1844         err_msg = os.strerror(errno_num)
# -> 1845     raise child_exception_type(errno_num, err_msg, err_filename)
#    1846 raise child_exception_type(err_msg)
#
# OSError: [Errno 8] Exec format error: '/home/ubuntu/.local/lib/python3.10/site-packages/selenium/webdriver/common/linux/selenium-manager'
#
# During handling of the above exception, another exception occurred:
#
# WebDriverException                        Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/selenium/webdriver/common/driver_finder.py:42, in DriverFinder.get_path(service, options)
#      41 try:
# ---> 42     path = SeleniumManager().driver_location(options) if path is None else path
#      43 except Exception as err:
#
# File ~/.local/lib/python3.10/site-packages/selenium/webdriver/common/selenium_manager.py:96, in SeleniumManager.driver_location(self, options)
#      94     args.append("--debug")
# ---> 96 result = self.run(args)
#      97 executable = result.split("\t")[-1].strip()
#
# File ~/.local/lib/python3.10/site-packages/selenium/webdriver/common/selenium_manager.py:118, in SeleniumManager.run(args)
#     117 except Exception as err:
# --> 118     raise WebDriverException(f"Unsuccessful command executed: {command}; {err}")
#     120 if completed_proc.returncode:
#
# WebDriverException: Message: Unsuccessful command executed: /home/ubuntu/.local/lib/python3.10/site-packages/selenium/webdriver/common/linux/selenium-manager --browser firefox --output json; [Errno 8] Exec format error: '/home/ubuntu/.local/lib/python3.10/site-packages/selenium/webdriver/common/linux/selenium-manager'
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchDriverException                     Traceback (most recent call last)
# Cell In[2], line 4
#       1 from selenium import webdriver
#       3 options = webdriver.FirefoxOptions()
# ----> 4 driver = webdriver.Firefox(options=options)
#       5 options.add_argument("--headless")
#       6 # chrome_options.headless = True # also works
#
# File ~/.local/lib/python3.10/site-packages/selenium/webdriver/firefox/webdriver.py:60, in WebDriver.__init__(self, options, service, keep_alive)
#      57 self.options = options if options else Options()
#      58 self.keep_alive = keep_alive
# ---> 60 self.service.path = DriverFinder.get_path(self.service, self.options)
#      61 self.service.start()
#      63 executor = FirefoxRemoteConnection(
#      64     remote_server_addr=self.service.service_url,
#      65     ignore_proxy=self.options._ignore_local_proxy,
#      66     keep_alive=self.keep_alive,
#      67 )
#
# File ~/.local/lib/python3.10/site-packages/selenium/webdriver/common/driver_finder.py:44, in DriverFinder.get_path(service, options)
#      42     path = SeleniumManager().driver_location(options) if path is None else path
#      43 except Exception as err:
# ---> 44     raise NoSuchDriverException(f"Unable to obtain {service.path} using Selenium Manager; {err}")
#      46 if path is None or not Path(path).is_file():
#      47     raise NoSuchDriverException(f"Unable to locate or obtain {service.path}")
#
# NoSuchDriverException: Message: Unable to obtain geckodriver using Selenium Manager; Message: Unsuccessful command executed: /home/ubuntu/.local/lib/python3.10/site-packages/selenium/webdriver/common/linux/selenium-manager --browser firefox --output json; [Errno 8] Exec format error: '/home/ubuntu/.local/lib/python3.10/site-packages/selenium/webdriver/common/linux/selenium-manager'
# ; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors/driver_location

# %%
import requests
import browser_cookie3
import pandas as pd
import json,os,random

def get_cookie_tdx():
    # 查找指定域名的指定Cookie值
    cookies = browser_cookie3.chrome(domain_name='wenda.tdx.com.cn')
#     cookies = 'Hm_lvt_5c4c948b141e4d66943a8430c3d600d0=1686342442,1687445719; Hm_lpvt_5c4c948b141e4d66943a8430c3d600d0=1687446049; LST=10; ASPSessionID=15860878705900324841'
#     return cookies
    for item in cookies:
        if item.name == "ASPSessionID" :
            # print('%s = %s' % (item.name, item.value))
            cookie_tdx = 'ASPSessionID=' + item.value + ';'
            return cookie_tdx

       
def set_headers():
    # 增加UserAgent，防止被反爬虫拦截
    user_agent_list = ["Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36",
                        "Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.99 Safari/537.36",
                        "Mozilla/5.0 (Windows NT 10.0; WOW64) Gecko/20100101 Firefox/61.0",
                        "Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/64.0.3282.186 Safari/537.36",
                        "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/62.0.3202.62 Safari/537.36",
                        "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2454.101 Safari/537.36",
                        "Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 6.0)",
                        "Mozilla/5.0 (Macintosh; U; PPC Mac OS X 10.5; en-US; rv:1.9.2.15) Gecko/20110303 Firefox/3.6.15",
                        ]
    headers = {
        'Cookie': get_cookie_tdx(),
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36'
    }
    return headers        
# https://wenda.tdx.com.cn/TQL?Entry=JNLPSE.getAllCode&RI=6BDF
url = 'https://wenda.tdx.com.cn/TQL?Entry=NLPSE.NLPQuery&RI=6BE0'
headers = set_headers()
data = [{"nlpse_id":"7248701856912769239","op_flag":1,"sec_code":"","order_field":"","dynamic_order":"","order_flag":"0","POS":"200","COUNT":"100","timestamps":0,"RANG":"AG"}]
res = requests.post(url=url,headers=headers,data=json.dumps(data))
res.encoding = res.apparent_encoding
res_json = res.json()
df = pd.DataFrame(res_json)
df = df.iloc[1:]
df2 = df.rename(columns=df.iloc[0])
df3 = df2.iloc[1:]

        
df3
# Out:
#   NaN   NaN NaN   NaN   NaN
# 2 NaN  None NaN  None  None

# %%
get_cookie_tdx()

# %%
import requests
import browser_cookie3
import pandas as pd
import json,os,random


class TDX_xiaoda:
    '''
    通达信-小达，使用chrome浏览器登录后，此工具可以自动获取ASPSessionID，并实现访问。
    '''
    def __init__(self,cookie=''):
        # 如果类传送Cookie则使用传参
        if cookie=='': 
            self.cookie = self._get_cookie_tdx()
        else:
            self.cookie = cookie

    def set_headers(self):
        # 增加UserAgent，防止被反爬虫拦截
        user_agent_list = ["Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36",
                            "Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.99 Safari/537.36",
                            "Mozilla/5.0 (Windows NT 10.0; WOW64) Gecko/20100101 Firefox/61.0",
                            "Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/64.0.3282.186 Safari/537.36",
                            "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/62.0.3202.62 Safari/537.36",
                            "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2454.101 Safari/537.36",
                            "Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 6.0)",
                            "Mozilla/5.0 (Macintosh; U; PPC Mac OS X 10.5; en-US; rv:1.9.2.15) Gecko/20110303 Firefox/3.6.15",
                            ]
        headers = {
            'Cookie': self.cookie,
            'User-Agent': random.choice(user_agent_list)}
        return headers

    def _get_cookie_tdx(self):
        # 查找指定域名的指定Cookie值
        cookies = browser_cookie3.chrome(domain_name='wenda.tdx.com.cn')
        for item in cookies:
            if item.name == "ASPSessionID" :
                # print('%s = %s' % (item.name, item.value))
                cookie_tdx = 'ASPSessionID=' + item.value + ';'
                return cookie_tdx

    def get_data_option(self,word='涨停股票'):
        '''
        获取提示参考
        :param word:
        :return:
        '''
        data = [{"op_flag":1,"question":word,"POS":0,"COUNT":10,"RANG":"AG"}]
        url = 'https://wenda.tdx.com.cn/TQL?Entry=NLPSE.QuestionImagine&RI='
        headers = self.set_headers()
        res = requests.post(url=url,data=json.dumps(data),headers=headers)
        res_json = res.json()
        return res_json
        
    def get_word_code(self,name='换手率2.8~15,量比2~20,OBV指标创新高,涨幅2~7,股价2~30'):
        '''
        :param name:
        :return:
        '''
        data = [{"message":name,"TDXID":"","wdbk":"","RANG":"AG"}]
        url = 'https://wenda.tdx.com.cn/TQL?Entry=NLPSE.StockSelect&RI='
        headers = self.set_headers()
        res = requests.post(url=url,headers=headers,data=json.dumps(data))
        res_json = res.json()
        code = res_json[-1][0]
        RI_code = res_json[0][3]
        return code, RI_code
        
    def get_all_option_data(self):
        '''
        获取全部参考
        :return:
        '''
        url = 'https://wenda.tdx.com.cn/TQL?Entry=NLPSE.SmartQuery&RI='
        headers = self.set_headers()
        data = [{"op_flag":1,"order_field":"","order_flag":1,"cond_json":"","POS":0,"COUNT":-1,"RANG":"AG"}]
        res = requests.post(url=url,headers=headers,data=json.dumps(data))
        res_json = res.json()
        df = pd.DataFrame(res_json)
        df = df.iloc[1:]
        df2 = df.rename(columns=df.iloc[0])
        df3 = df2.iloc[1:]
        return df3
        
#     def get_word_result(self,word='今日涨停',try_times = 30):
#         '''
#         根据关键字分析后获取数据
#         :param word:关键字
#         :return:字典，包含状态和数据
#         '''
#         while try_times>0:
            
#             code, RI_code = self.get_word_code(name=word)
#             url = 'https://wenda.tdx.com.cn/TQL?Entry=NLPSE.NLPQuery&RI=' + RI_code
#             headers = self.set_headers()
#             data = [{"nlpse_id":code,"POS":0,"COUNT":6000,"order_field":"","dynamic_order":"","order_flag":"","timestamps":0,"op_flag":1,"screen_type":1,"RANG":"AG"}]
#             res = requests.post(url=url,headers=headers,data=json.dumps(data))
#             res.encoding = res.apparent_encoding
# #             text = res.content.decode('utf-8')
#             print(res.text)
#             res_json = res.json()
#             if len(res_json[1])<4:
#                 try_times -= 1
#                 print('获取信息失败，剩余'+str(try_times)+'次尝试机会，再次尝试连接......')
#             else:
#                 # print(text)
#                 df = pd.DataFrame(res_json)
#                 df = df.iloc[1:]
#                 df2 = df.rename(columns=df.iloc[0])
#                 df3 = df2.iloc[2:]
#                 return {
#                         "success": True,
#                         "df_data":df3.round(3)
#                     }
#         return {
#             "success": False,
#             "msg": '获取行情信息结果为None'
#         }

    def get_word_result(self,word='今日涨停'):
        '''
        根据关键字分析后获取数据
        :param word:关键字
        :return:字典，包含状态和数据
        '''

        code, RI_code = self.get_word_code(name=word)
        url = 'https://wenda.tdx.com.cn/TQL?Entry=NLPSE.NLPQuery&RI=' + RI_code
        headers = self.set_headers()
        data = [{"nlpse_id":code,"POS":100,"COUNT":100,"order_field":"","dynamic_order":"","order_flag":"","timestamps":0,"op_flag":1,"screen_type":1,"RANG":"AG"}]
        res = requests.post(url=url,headers=headers,data=json.dumps(data))
        res.encoding = res.apparent_encoding
#             text = res.content.decode('utf-8')
        res_json = res.json()

        df = pd.DataFrame(res_json)
        df = df.iloc[1:]
        df2 = df.rename(columns=df.iloc[0])
        df3 = df2.iloc[2:]
        return {"success": True,"df_data":df3.round(3)}

    
# ===============表格美化输出===============
def df_table(df,index):
    import prettytable as pt
    #利用prettytable对输出结果进行美化,index为索引列名:df_table(df,'market')
    tb = pt.PrettyTable()
    # 如果为trade_time为index转换为日期类型，其它不用管。
    if index == "trade_time":
        df = df.set_index(index)
        df.index = pd.DatetimeIndex(df.index)
    # df.reset_index(level=None, drop=True, inplace=True, col_level=0, col_fill='')
    df = df.reset_index(drop = True)
    tb.add_column(index,df.index)#按date排序
    for col in df.columns.values:#df.columns.values的意思是获取列的名称
        # print('col',col)
        # print('df[col]',df[col])
        tb.add_column(col, df[col])
    print(tb)


if __name__=='__main__':
    # 以下两种方法均可以，推荐方法2。注册请自行搞定。
    # 方法1：使用任意浏览器登录https://wenda.tdx.com.cn/，并按F12查看网络，找到Cookie复制后替换这里ASPSessionID后数值即可使用。注意不要带分号。
    # xd = TDX_xiaoda(cookie = 'ASPSessionID=xxxxxxxxxx') 
    # 方法2：使用Chrome浏览器登录https://wenda.tdx.com.cn/后，无需手工查找Cookie，程序会自动获取ASPSessionID，并实现访问。但必须使用Chrome浏览器。
    xd = TDX_xiaoda() 
        
#     if 0:
#         #可能获取不到
#         ret = xd.get_data_option(word='沪深A股,换手率1%~5%')
#         print(ret)
#         #获取问题转代码
#         ret = xd.get_word_code(name='沪深A股,换手率1%~5%')
#         print(ret)
#         #获取全部的参考，具体看通达信
#         ret = xd.get_all_option_data()
#         # print(ret)
#         df_table(ret,'df')
    
#     if 1:
        #获取问题的结果
    words = '所属概念，所属主题，公司地位，主营业务，研究行业' # 连板 3连板 今日涨停 20230201涨停 北向资金 板块 大单抢筹 MACD背离
    ret = xd.get_word_result(word=words)
    if ret['success']:
        df = ret['df_data']
        # print(df)
#         df_table(df,'df')
#             filename = os.path.dirname(__file__)+'\\'+'通达信-小达选股_'+words+'.xlsx'
#             df.to_excel(filename)
#             print('选股完成，结果写入：',filename)
df['所属概念'] = df['所属概念'].str.replace('【@','').str.replace('@】','')
df['所属主题'] = df['所属主题'].str.replace('【@','').str.replace('@】','')
df['所属通达信研究行业'] = df['所属通达信研究行业'].str.replace('【@','').str.replace('@】','')
df[['sec_code','sec_name','所属通达信研究行业','主营关键字','投资逻辑','所属概念','所属主题']]
# Out:
#     sec_code sec_name 所属通达信研究行业           主营关键字                     投资逻辑  \
# 100                          参股新三板;消费金融;文心一言;罗素中盘;华为概念
# 101                               甲醇;罗素中盘;丁辛醇;医保目录;清华系
# 102                            硅能源;多晶硅;冰雪运动;定向增发;参股新三板
#
# [100 rows x 7 columns]

# %%
ret
# Out:
# {'success': True,
#  'df_data':      POS market sec_code sec_name now_price     chg  \
#  3    101      0   002362     汉王科技     25.48  -10.00
#  4    102      0   000988     华工科技     35.17   -7.08
#  5    103      0   300058     蓝色光标      9.95   -9.30
#  6    104      0   300496     中科创达    102.70   -3.75
#  7    105      0   300096      易联众      6.18   -5.94
#  ..   ...    ...      ...      ...       ...     ...
#  98   196      0   300161     华中数控     54.90   -6.63
#  99   197      0   002975     博杰股份     39.50   -3.94
#  100  198      0   002195     二三四五      2.87   -4.01
#  101  199      0   000990     诚志股份      7.32   -0.81
#  102  200      0   300472     新元科技     10.20   -3.95
#
#                                                    所属概念 概念个数0#  \
#  3    ChatGPT;智慧政务;基因概念;云计算;跨境电商;口罩防护;电子纸;大数据;机器视觉;电...     16
#  4    创投概念;汽车电子;高压快充;物联网;智慧城市;特斯拉;新材料;苹果概念;量子科技;光通信;...     16
#  5    网红经济;腾讯概念;ChatGPT;NFT概念;职业教育;人工智能;网络游戏;元宇宙;抖音概...     16
#  6    英伟达;物联网;区块链;人工智能;无人驾驶;元宇宙;边缘计算;大数据;虚拟现实;混合现实;华...     16
#  7    家庭医生;区块链;Web3概念;腾讯概念;海峡西岸;大数据;智慧城市;ChatGPT;DRG...     16
#  ..                                                 ...    ...
#  98   工业母机;锂电池;新能源车;国防军工;工业互联;阿里概念;智能机器;高端装备;职业教育;口罩...     14
#  99   特斯拉;小米概念;减速器;人工智能;含可转债;智能机器;混合现实;苹果概念;机器视觉;英伟达...     14
#  100  云游戏;云计算;创投概念;人工智能;百度概念;国产软件;大数据;网络游戏;元宇宙;抖音概念;...     14
#  101  工业大麻;NMN概念;医美概念;雄安新区;氢能源;新冠药;燃料电池;民营医院;工业气体;PO...     14
#  102  体育概念;智慧城市;算力概念;云游戏;东数西算;一带一路;云计算;5G概念;智能机器;光伏;...     14
#
#                                                    所属主题 主题个数  ...        成立日期  \
#  3    智能汽车;虹膜识别;虚拟数字人;京津冀;触摸屏;数字中国;华为鲲鹏;空气净化;在线教育;基因...   17  ...  2005.12.19
#  4    全息概念;比亚迪概念;武汉规划;3D玻璃;传感器;东湖高新区;射频识别;光器件;二维码识别;...   16  ...  1999.07.28
#  5    短视频概念;虚拟数字人;国资入股;股权拍卖;Facebook概念;文心一言;参股新三板;新媒...   15  ...  2002.11.04
#  6    寒武纪概念;智能汽车;滴滴概念;智能电视;华为概念;发行GDR;理想汽车概念;小鹏汽车概念;...   14  ...  2008.03.07
#  7    华为概念;生物安全;人力资源服务;问询函;蚂蚁金服概念;参股新三板;医药安全;移动支付;托育...   14  ...  2000.07.14
#  ..                                                 ...  ...  ...         ...
#  98                     卓尔系;医疗器械概念;武汉规划;医疗机器人;红外成像;数控系统    6  ...  2000.11.24
#  99                     横琴新区;声学;人民币贬值受益;比亚迪概念;罗素小盘;华为概念    6  ...  2005.05.30
#  100                          参股新三板;消费金融;文心一言;罗素中盘;华为概念    5  ...  1989.04.07
#  101                               甲醇;罗素中盘;丁辛醇;医保目录;清华系    5  ...  1998.10.09
#  102                            硅能源;多晶硅;冰雪运动;定向增发;参股新三板    5  ...  2003.09.24
#
#      法人代表                                 注册地址        注册资金(元)  \
#  3    刘迎建                   北京市海淀区东北旺西路8号5号楼三层   244454646.00
#  4    马新强     湖北省武汉市东湖高新技术开发区华中科技大学科技园华工科技本部大楼  1005502707.00
#  5    潘安民          北京市朝阳区酒仙桥北路9号（厂区）10幢二层A5-01  2491037834.00
#  6    赵鸿飞     北京市海淀区清华东路9号创达大厦1层101-105室（东升地区）   457478344.00
#  7     张曦                福建省厦门市软件园二期观日路18号502室   430000000.00
#  ..   ...                                  ...            ...
#  98   陈吉红                     湖北省武汉市东湖开发区华工科技园   198696906.00
#  99   王兆春        广东省珠海市香洲区福田路10号厂房1一楼-1、二、三、四楼   139380142.00
#  100  陈于冰                   上海市徐汇区宜山路700号85幢6楼  5724847663.00
#  101  龙大伟               江西省南昌市经济技术开发区玉屏东大街299号  1215237535.00
#  102  朱业胜  江西省抚州市临川区才都工业园区科技园路666号临川高新科技产业园办公楼   275258621.00
#
#                                                    主营范围 营业性质             行业门类  \
#  3    技术开发、技术转让、技术咨询、技术服务、技术培训；电脑图文设计、制作；计算机网络安装、维修；...                   制造业
#  4    提供激光智能装备、激光自动化产线、激光全息综合防伪产品、传感器、汽车电子产品、光通信产品的研...                   制造业
#  5    大数据、计算机软件、网络、系统集成的技术开发、技术转让、技术服务、技术咨询；企业策划；企业形...              租赁和商务服务业
#  6    开发计算机软件；销售自行开发的产品；技术咨询、技术服务；计算机软件技术培训；计算机系统服务；...       信息传输、软件和信息技术服务业
#  7    （研发、设计和生产智能卡、银行卡；销售智能卡）其他未列明信息技术服务业（不含需经许可审批的项...       信息传输、软件和信息技术服务业
#  ..                                                 ...  ...              ...
#  98   数控系统、机器人、智能生产线、新能源汽车设计和配套产品、机电一体化、电子、计算机、激光、通信...                   制造业
#  99   电子测试设备、工业自动化设备的研发、生产和销售，相关设备维修、升级（测试）及相关商务服务和技...                   制造业
#  100  计算机软、硬件系统及相关系统的集成、开发、咨询、销售及服务，经营本企业自产产品的出口业务和本...       信息传输、软件和信息技术服务业
#  101  本企业自产产品及相关技术的出口业务（国家限定公司经营或禁止出口的商品除外)：本企业的进料加工...                   制造业
#  102  智能装备、智能机器人、机电一体化设备的技术开发；基础软件服务；机械设备租赁（不含汽车租赁）；...                   制造业
#
#      所属通达信研究行业  研究行业代码 研究行业市场代码
#  3        新兴软件  881358        1
#  4        激光设备  881316        1
#  5       互联网广告  881371        1
#  6      行业应用软件  881357        1
#  7      行业应用软件  881357        1
#  ..        ...     ...      ...
#  98       机床制造  881296        1
#  99     工业控制设备  881315        1
#  100   产联网综合服务  881367        1
#  101       煤化工  881027        1
#  102    其他专用设备  881309        1
#
#  [100 rows x 23 columns]}

# %%
df.to_csv('tdx_data.csv',index=False)

# %%
xd.get_word_code(name='沪深A股,换手率1%~5%')
# Out:
# ('7248701856913083995', '6BE0')

# %%
res_json
